# %% [markdown]
# # scitex.writer -- LaTeX Manuscript Compilation

# %%
import scitex as stx

# %% [markdown]
# ## Compile Manuscript

# %%
# Compile LaTeX manuscript (requires LaTeX installation + project directory)
# stx.writer.compile_manuscript("paper/")
print("stx.writer.compile_manuscript(dir) compiles main.tex -> PDF")
# Out:
# stx.writer.compile_manuscript(dir) compiles main.tex -> PDF

# %% [markdown]
# ## Add Figures and Tables

# %%
# Add figures and tables to a manuscript project
# stx.writer.add_figure(project_dir="paper/", label="fig:accuracy",
#     caption="Classification accuracy.", path="figures/accuracy.pdf")
# stx.writer.add_table(project_dir="paper/", label="tab:demographics",
#     caption="Participant demographics.", path="tables/demographics.csv")
print("add_figure(dir, label, caption, path) and add_table() manage LaTeX includes")
# Out:
# add_figure(dir, label, caption, path) and add_table() manage LaTeX includes

# %% [markdown]
# ## Bibliography Management

# %%
# Bibliography management
# stx.writer.list_bibentries("paper/")
# stx.writer.add_bibentry(project_dir="paper/", doi="10.1038/s41586-024-07804-3")
print("list_bibentries(dir) and add_bibentry(dir, doi) manage BibTeX entries")
# Out:
# list_bibentries(dir) and add_bibentry(dir, doi) manage BibTeX entries

# %% [markdown]
# ## Claims (linked to Clew verification)

# %%
# Claims linked to Clew verification
# stx.writer.add_claim(project_dir="paper/", claim_type="statistical",
#     text="Accuracy was above chance (p < 0.001)", source_session="./sessions/...")
print("add_claim() registers manuscript assertions traceable via Clew DAG")
# Out:
# add_claim() registers manuscript assertions traceable via Clew DAG
